# %%
! pip install matplotlib ipympl
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.widgets import RectangleSelector
from skimage.io import imread
class Selector:
    def __init__(self, ax):
        self.RS = RectangleSelector(ax, self.line_select_callback,
                                     useblit=True,
                                       button=[1, 3],  
                                       minspanx=5, minspany=5,
                                       spancoords='pixels',
                                       interactive=True)
        self.bbox = [None, None, None, None]
        
    def line_select_callback(self,eclick, erelease):
        'eclick and erelease are the press and release events'
        x1, y1 = eclick.xdata, eclick.ydata
        x2, y2 = erelease.xdata, erelease.ydata
        self.bbox = [int(y1), int(y2), int(x1), int(x2)]
    def get_bbox(self):
        return self.bbox

# Display the image as usual
img = imread('degraded.tif')
ax = plt.gca()
ax.imshow(img)
# Create Selector class with the current plot axis
select = Selector(ax)
# Show the result
plt.show()
# Out:
# Requirement already satisfied: matplotlib in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: ipympl in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (0.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: ipython-genutils in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: ipython<9 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipympl) (8.29.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipympl) (8.1.5)
# Requirement already satisfied: traitlets<6 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipython<9->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipython<9->ipympl) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipython<9->ipympl) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipython<9->ipympl) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipython<9->ipympl) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipython<9->ipympl) (4.12.2)
# Requirement already satisfied: colorama in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.13)
# Requirement already satisfied: six>=1.5 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from stack-data->ipython<9->ipympl) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from stack-data->ipython<9->ipympl) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\paige\documents\575\lab4\.venv\lib\site-packages (from stack-data->ipython<9->ipympl) (0.2.3)

# %%
#After drawing the box, retrieve the bounding box
# This is in [row_low, row_high, col_low, col_high] format.
print(select.bbox)
# Out:
# [None, None, None, None]
